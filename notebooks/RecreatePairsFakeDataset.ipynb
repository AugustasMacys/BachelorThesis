# %%
import pandas as pd
import os

# %%
fake_dataframe_path = r"D:/deepfakes/dataframes/dataframes_pairs_updated/fake_crops.csv"
real_dataframe_path = r"D:/deepfakes/dataframes/dataframes_pairs_updated/real_crops.csv"

# %%
df = pd.read_csv(fake_dataframe_path)

# %%
df
# Out:
#                                                 image_path  label
# 0        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 1        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 2        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 3        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 4        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# ...                                                    ...    ...
# 1486962  C:\Users\Augustas\Documents\training_fake_face...      1
# 1486963  C:\Users\Augustas\Documents\training_fake_face...      1
# 1486964  C:\Users\Augustas\Documents\training_fake_face...      1
# 1486965  C:\Users\Augustas\Documents\training_fake_face...      1
# 1486966  C:\Users\Augustas\Documents\training_fake_face...      1
#
# [1486967 rows x 2 columns]

# %%
paths = df.image_path

# %%
fake_faces_2 = paths[285779:504833]

# %%
fake_faces_2
# Out:
# 285779    D:\deepfakes\training_fake_faces2\wnaweyzlqh\w...
# 285780    D:\deepfakes\training_fake_faces2\wnaweyzlqh\w...
# 285781    D:\deepfakes\training_fake_faces2\wnaweyzlqh\w...
# 285782    D:\deepfakes\training_fake_faces2\wnaweyzlqh\w...
# 285783    D:\deepfakes\training_fake_faces2\wnaweyzlqh\w...
#                                 ...
# 504828    D:\deepfakes\training_fake_faces2\qxbhxtuvmv\q...
# 504829    D:\deepfakes\training_fake_faces2\qxbhxtuvmv\q...
# 504830    D:\deepfakes\training_fake_faces2\qxbhxtuvmv\q...
# 504831    D:\deepfakes\training_fake_faces2\qxbhxtuvmv\q...
# 504832    D:\deepfakes\training_fake_faces2\qxbhxtuvmv\q...
# Name: image_path, Length: 219054, dtype: object

# %%
example = fake_faces_2[285779]

# %%
example.replace("training_fake_faces2", "training_fake_faces")
# Out:
# 'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_0.png'

# %%
fake_faces_2 = [x.replace("training_fake_faces2", "training_fake_faces") for x in fake_faces_2]

# %%
fake_faces_2
# Out:
# ['D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_0.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_20.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_40.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_60.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_80.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_100.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_120.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_140.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_160.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_180.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_200.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_220.png',
#  'D:\\deepfakes\\training_fake_faces\\wnaweyzlqh\\wnaweyzlqh_240.png',
# ...

# %%
fake_faces_3 = paths[504833:1216926]

# %%
fake_faces_3
# Out:
# 504833     D:\deepfakes\training_fake_faces3\rpxnyljmsf\r...
# 504834     D:\deepfakes\training_fake_faces3\rpxnyljmsf\r...
# 504835     D:\deepfakes\training_fake_faces3\rpxnyljmsf\r...
# 504836     D:\deepfakes\training_fake_faces3\rpxnyljmsf\r...
# 504837     D:\deepfakes\training_fake_faces3\rpxnyljmsf\r...
#                                  ...
# 1216921    D:\deepfakes\training_fake_faces3\mecsubivra\m...
# 1216922    D:\deepfakes\training_fake_faces3\mecsubivra\m...
# 1216923    D:\deepfakes\training_fake_faces3\mecsubivra\m...
# 1216924    D:\deepfakes\training_fake_faces3\mecsubivra\m...
# 1216925    D:\deepfakes\training_fake_faces3\mecsubivra\m...
# Name: image_path, Length: 712093, dtype: object

# %%
fake_faces_3 = [x.replace("training_fake_faces3", "training_fake_faces") for x in fake_faces_3]

# %%
fake_faces_3
# Out:
# ['D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_0.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_20.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_40.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_60.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_80.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_100.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_120.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_140.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_160.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_180.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_200.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_220.png',
#  'D:\\deepfakes\\training_fake_faces\\rpxnyljmsf\\rpxnyljmsf_240.png',
# ...

# %%
fake_faces_4 = paths[1216926:]

# %%
fake_faces_4
# Out:
# 1216926    C:\Users\Augustas\Documents\training_fake_face...
# 1216927    C:\Users\Augustas\Documents\training_fake_face...
# 1216928    C:\Users\Augustas\Documents\training_fake_face...
# 1216929    C:\Users\Augustas\Documents\training_fake_face...
# 1216930    C:\Users\Augustas\Documents\training_fake_face...
#                                  ...
# 1486962    C:\Users\Augustas\Documents\training_fake_face...
# 1486963    C:\Users\Augustas\Documents\training_fake_face...
# 1486964    C:\Users\Augustas\Documents\training_fake_face...
# 1486965    C:\Users\Augustas\Documents\training_fake_face...
# 1486966    C:\Users\Augustas\Documents\training_fake_face...
# Name: image_path, Length: 270041, dtype: object

# %%
example = fake_faces_4[1216926]

# %%
example
# Out:
# 'C:\\Users\\Augustas\\Documents\\training_fake_faces4\\opxytgekxt\\opxytgekxt_0.png'

# %%
example.replace(r"C:\Users\Augustas\Documents\training_fake_faces4", r"D:\deepfakes\training_fake_faces")
# Out:
# 'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_0.png'

# %%
fake_faces_4 = [x.replace(r"C:\Users\Augustas\Documents\training_fake_faces4", r"D:\deepfakes\training_fake_faces") for x in fake_faces_4]

# %%
fake_faces_4
# Out:
# ['D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_0.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_20.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_40.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_60.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_80.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_100.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_120.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_140.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_160.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_180.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_200.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_220.png',
#  'D:\\deepfakes\\training_fake_faces\\opxytgekxt\\opxytgekxt_240.png',
# ...

# %%
fake_faces = list(paths[:285779])

# %%
fake_faces[-1]
# Out:
# 'D:\\deepfakes\\training_fake_faces\\ohmkmcfxul\\ohmkmcfxul_280.png'

# %%
all_fake_faces_updated = fake_faces + fake_faces_2 + fake_faces_3 + fake_faces_4

# %%
len(all_fake_faces_updated)
# Out:
# 1486967

# %%
len(df)
# Out:
# 1486967

# %%
df["image_path"] = all_fake_faces_updated

# %%
df.to_csv(fake_dataframe_path, index=False)

# %% [markdown]
# ## Remove unexistant

# %%
indexes_to_delete = []
for i in range(len(all_fake_faces_updated)):
    if not os.path.isfile(all_fake_faces_updated[i]):
        indexes_to_delete.append(i)

# %%
indexes_to_delete
# Out:
# []

# %%
df_real = pd.read_csv(real_dataframe_path)

# %%
df_real
# Out:
#                                                 image_path  label
# 0        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 1        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 2        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 3        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 4        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# ...                                                    ...    ...
# 1486962  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486963  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486964  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486965  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486966  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
#
# [1486967 rows x 2 columns]

# %%
real_faces = df_real["image_path"]
indexes_to_delete = []
for i in range(len(real_faces)):
    if not os.path.isfile(real_faces[i]):
        indexes_to_delete.append(i)

# %%
indexes_to_delete
# Out:
# []

# %%
masks = [x.replace("training_real_faces", "mask_xray_fake_new") for x in list(real_faces)]

# %%
masks
# Out:
# ['D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_0.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_20.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_40.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_60.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_80.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_100.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_120.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_140.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_160.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_180.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_200.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_220.png',
#  'D:\\deepfakes\\mask_xray_fake_new\\wynotylpnm\\wynotylpnm_240.png',
# ...

# %%
indexes_to_delete = []
for i in range(len(masks)):
    if not os.path.isfile(masks[i]):
        indexes_to_delete.append(i)

# %%
len(indexes_to_delete)
# Out:
# 1553

# %%
indexes_to_delete
# Out:
# [3352,
#  9938,
#  15427,
#  16143,
#  16145,
#  16197,
#  16563,
#  21868,
#  34031,
#  35593,
#  38046,
#  41219,
#  45152,
#  48043,
#  48717,
#  49157,
#  49158,
#  51678,
#  56027,
#  56280,
#  56379,
#  56380,
#  56381,
#  56382,
#  58355,
#  58564,
#  58968,
#  61976,
#  61979,
#  61982,
#  70809,
#  70972,
#  70976,
#  71060,
#  71071,
#  74251,
#  74252,
#  93771,
#  95127,
#  95642,
#  95644,
#  95647,
#  95947,
#  96043,
#  103666,
#  103667,
#  103668,
#  103675,
#  103679,
#  103680,
#  103693,
#  103694,
#  103695,
#  103698,
#  103700,
#  103730,
#  103731,
#  103732,
#  103733,
#  103737,
#  103767,
#  103768,
#  103769,
#  103770,
#  103800,
#  103804,
#  103809,
#  103817,
#  103818,
#  103820,
#  103821,
#  103825,
#  103826,
#  103834,
#  103836,
#  103838,
#  103843,
#  103867,
#  103869,
#  103870,
#  103894,
#  103895,
#  103900,
#  103901,
#  103903,
#  103904,
#  103905,
#  103906,
#  105519,
#  105520,
#  105521,
#  105525,
#  105774,
#  105780,
#  107325,
# ...

# %%
real_faces[3352]
# Out:
# 'D:\\deepfakes\\training_real_faces\\nawtezpgnm\\nawtezpgnm_0.png'

# %%
# for index in sorted(indexes_to_delete, reverse=True):
#     del real_faces[index]
    
# for index in sorted(indexes_to_delete, reverse=True):
#     del all_fake_faces_updated[index]

# %%
len(real_faces)
# Out:
# 1485414

# %%
len(all_fake_faces_updated)
# Out:
# 1485414

# %%
new_real_df = pd.DataFrame(real_faces, columns =['image_path'])

new_fake_df = pd.DataFrame(all_fake_faces_updated, columns =['image_path'])

# %%
new_real_df["label"] = 0
new_fake_df["label"] = 1

# %%
new_real_df
# Out:
#                                                 image_path  label
# 0        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 1        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 2        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 3        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# 4        D:\deepfakes\training_real_faces\wynotylpnm\wy...      0
# ...                                                    ...    ...
# 1486962  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486963  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486964  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486965  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
# 1486966  D:\deepfakes\training_real_faces\mdpyllcmrj\md...      0
#
# [1485414 rows x 2 columns]

# %%
new_fake_df
# Out:
#                                                 image_path  label
# 0        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 1        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 2        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 3        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# 4        D:\deepfakes\training_fake_faces\owxbbpjpch\ow...      1
# ...                                                    ...    ...
# 1485409  D:\deepfakes\training_fake_faces\tolotyowoy\to...      1
# 1485410  D:\deepfakes\training_fake_faces\tolotyowoy\to...      1
# 1485411  D:\deepfakes\training_fake_faces\tolotyowoy\to...      1
# 1485412  D:\deepfakes\training_fake_faces\tolotyowoy\to...      1
# 1485413  D:\deepfakes\training_fake_faces\tolotyowoy\to...      1
#
# [1485414 rows x 2 columns]

# %%
new_real_df.to_csv(r"D:\deepfakes\dataframes\dataframes_pairs_updated\real_pairs_xray.csv" , index=False)
new_fake_df.to_csv(r"D:\deepfakes\dataframes\dataframes_pairs_updated\fake_pairs_xray.csv" , index=False)

# %% [markdown]
# ## Testing dataframe

# %%
test_dataframe = r"D:/deepfakes/dataframes/faces_validation.csv"

test_df = pd.read_csv(test_dataframe)

# %%
paths = test_df["image_path"]

# %%
paths
# Out:
# 0          D:/deepfakes/validation_faces\4000_0.png
# 1        D:/deepfakes/validation_faces\4000_100.png
# 2        D:/deepfakes/validation_faces\4000_120.png
# 3        D:/deepfakes/validation_faces\4000_140.png
# 4        D:/deepfakes/validation_faces\4000_160.png
#                             ...
# 57529    D:/deepfakes/validation_faces\7999_260.png
# 57530    D:/deepfakes/validation_faces\7999_280.png
# 57531     D:/deepfakes/validation_faces\7999_40.png
# 57532     D:/deepfakes/validation_faces\7999_60.png
# 57533     D:/deepfakes/validation_faces\7999_80.png
# Name: image_path, Length: 57534, dtype: object

# %%
example = paths[0]

# %%
example
# Out:
# 'D:/deepfakes/validation_faces\\4000_0.png'

# %%
first_part = example[:29]

# %%
first_part
# Out:
# 'D:/deepfakes/validation_faces'

# %%
folder = example[30:34]

# %%
folder
# Out:
# '4000'

# %%
identifier = example[30:]

# %%
identifier
# Out:
# '4000_0.png'

# %%
final = os.path.join(first_part, folder, identifier)

# %%
final
# Out:
# 'D:/deepfakes/validation_faces\\4000\\4000_0.png'

# %%
updated_validation_paths = [os.path.join(x[:29], x[30:34], x[30:]) for x in paths]

# %%
len(updated_validation_paths)
# Out:
# 57534

# %%
test_df["image_path"] = updated_validation_paths

# %%
test_df.to_csv(r"D:/deepfakes/dataframes/faces_validation_new.csv", index=False)
