# %%
import pandas as pd
import pickle
import os

# %%
path_3D_df = r"D:/deepfakes/3dcnn_dataframe.csv"

# %%
df = pd.read_csv(path_3D_df)

# %%
df
# Out:
#                                  real_image_folder  \
# 0      D:\deepfakes\training_real_faces\wynotylpnm
# 1      D:\deepfakes\training_real_faces\wclvkepakb
# 2      D:\deepfakes\training_real_faces\vpmyeepbep
# 3      D:\deepfakes\training_real_faces\jawgcggquk
# 4      D:\deepfakes\training_real_faces\qarqtkvgby
# ...                                            ...
# 99995  D:\deepfakes\training_real_faces\cnvquynriz
# 99996  D:\deepfakes\training_real_faces\moyljhcxok
# 99997  D:\deepfakes\training_real_faces\ikebomnsiq
# 99998  D:\deepfakes\training_real_faces\kudvvlgiff
# 99999  D:\deepfakes\training_real_faces\hysmzkqsdl
#
#                                  fake_image_folder
# 0      D:\deepfakes\training_fake_faces\owxbbpjpch
# 1      D:\deepfakes\training_fake_faces\htorvhbcae
# 2      D:\deepfakes\training_fake_faces\fckxaqjbxk
# 3      D:\deepfakes\training_fake_faces\sphirandia
# 4      D:\deepfakes\training_fake_faces\vsmadeuczx
# ...

# %%
real_image_folder_paths = df["real_image_folder"].values

# %%
real_image_folder_paths
# Out:
# array(['D:\\deepfakes\\training_real_faces\\wynotylpnm',
#        'D:\\deepfakes\\training_real_faces\\wclvkepakb',
#        'D:\\deepfakes\\training_real_faces\\vpmyeepbep', ...,
#        'D:\\deepfakes\\training_real_faces\\ikebomnsiq',
#        'D:\\deepfakes\\training_real_faces\\kudvvlgiff',
#        'D:\\deepfakes\\training_real_faces\\hysmzkqsdl'], dtype=object)

# %%
df["real_image_folder"] = df["real_image_folder"].str.slice(start=13).str.replace(os.path.sep, '/')

# %%
df["fake_image_folder"] = df["fake_image_folder"].str.slice(start=13).str.replace(os.path.sep, '/')

# %%
df
# Out:
#                     real_image_folder               fake_image_folder
# 0      training_real_faces/wynotylpnm  training_fake_faces/owxbbpjpch
# 1      training_real_faces/wclvkepakb  training_fake_faces/htorvhbcae
# 2      training_real_faces/vpmyeepbep  training_fake_faces/fckxaqjbxk
# 3      training_real_faces/jawgcggquk  training_fake_faces/sphirandia
# 4      training_real_faces/qarqtkvgby  training_fake_faces/vsmadeuczx
# ...                               ...                             ...
# 99995  training_real_faces/cnvquynriz  training_fake_faces/uowiocuqqt
# 99996  training_real_faces/moyljhcxok  training_fake_faces/tnaeehpcnb
# 99997  training_real_faces/ikebomnsiq  training_fake_faces/pdooqxqfrm
# 99998  training_real_faces/kudvvlgiff  training_fake_faces/djjdcnhlma
# 99999  training_real_faces/hysmzkqsdl  training_fake_faces/ohmkmcfxul
#
# [100000 rows x 2 columns]

# %%
path_save = r"D:\deepfakes\dataframes_google_cloud_3d\3dcnn_dataframe_cloud.csv"

# %%
df.to_csv(path_save, index=False)

# %%
path_3D_df_testing = r"D:/deepfakes/3dtesting_dataframe.csv"

# %%
df_testing = pd.read_csv(path_3D_df_testing)

# %%
df_testing["faces_folder"] = df_testing["faces_folder"].str.slice(start=13).str.replace(os.path.sep, '/')

# %%
df_testing
# Out:
#                faces_folder  label
# 0     validation_faces/4000      1
# 1     validation_faces/4001      1
# 2     validation_faces/4002      1
# 3     validation_faces/4003      0
# 4     validation_faces/4004      0
# ...                     ...    ...
# 3995  validation_faces/7995      0
# 3996  validation_faces/7996      0
# 3997  validation_faces/7997      0
# 3998  validation_faces/7998      1
# 3999  validation_faces/7999      1
#
# [4000 rows x 2 columns]

# %%
path_save = r"D:\deepfakes\dataframes_google_cloud_3d\testing_dataframe_cloud.csv"
df_testing.to_csv(path_save, index=False)

# %%
real_folders_to_identifiers_path = "real_folder_to_identifiers.pkl"
fake_folders_to_identifiers_path = "fake_folder_to_identifiers.pkl"

# %%
with open(real_folders_to_identifiers_path, 'rb') as handle:
    real_folder_to_identifiers = pickle.load(handle)
    
with open(fake_folders_to_identifiers_path, 'rb') as handle:
    fake_folder_to_identifiers = pickle.load(handle)

# %%
fake_folder_to_identifiers
# Out:
# {'D:\\deepfakes\\training_fake_faces\\owxbbpjpch': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\training_fake_faces\\htorvhbcae': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\training_fake_faces\\fckxaqjbxk': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\training_fake_faces\\sphirandia': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\training_fake_faces\\vsmadeuczx': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\training_fake_faces\\ohaqlzfnuv': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
# ...

# %%
real_folder_to_identifiers = {k[13:].replace(os.path.sep, '/'): v for (k, v) in real_folder_to_identifiers.items()}
fake_folder_to_identifiers = {k[13:].replace(os.path.sep, '/'): v for (k, v) in fake_folder_to_identifiers.items()}

# %%
fake_folder_to_identifiers
# Out:
# {'training_fake_faces/owxbbpjpch': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_fake_faces/htorvhbcae': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_fake_faces/fckxaqjbxk': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_fake_faces/sphirandia': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_fake_faces/vsmadeuczx': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_fake_faces/ohaqlzfnuv': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
# ...

# %%
real_folder_to_identifiers
# Out:
# {'training_real_faces/wynotylpnm': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_real_faces/wclvkepakb': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_real_faces/vpmyeepbep': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_real_faces/jawgcggquk': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_real_faces/qarqtkvgby': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'training_real_faces/sttnfyptum': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
# ...

# %%
with open(r'D:\deepfakes\google_cloud_pickle_objects\real_folder_to_identifiers.pickle', 'wb') as handle:
    pickle.dump(real_folder_to_identifiers, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open(r'D:\deepfakes\google_cloud_pickle_objects\fake_folder_to_identifiers.pickle', 'wb') as handle:
    pickle.dump(fake_folder_to_identifiers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
testing_folder_to_identifiers_path = r"D:/deepfakes/testing_folder_to_identifiers.pkl"


with open(testing_folder_to_identifiers_path, 'rb') as handle:
    testing_folder_to_identifiers = pickle.load(handle)

# %%
testing_folder_to_identifiers
# Out:
# {'D:\\deepfakes\\validation_faces\\4000': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280,
#   300],
#  'D:\\deepfakes\\validation_faces\\4001': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\validation_faces\\4002': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\validation_faces\\4003': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280,
#   300],
#  'D:\\deepfakes\\validation_faces\\4004': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'D:\\deepfakes\\validation_faces\\4005': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
# ...

# %%
testing_folder_to_identifiers = {k[13:].replace(os.path.sep, '/'): v for (k, v) in testing_folder_to_identifiers.items()}

# %%
with open(r'D:\deepfakes\google_cloud_pickle_objects\testing_folder_to_identifiers.pickle', 'wb') as handle:
    pickle.dump(testing_folder_to_identifiers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
testing_folder_to_identifiers
# Out:
# {'validation_faces/4000': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280,
#   300],
#  'validation_faces/4001': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'validation_faces/4002': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'validation_faces/4003': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280,
#   300],
#  'validation_faces/4004': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'validation_faces/4005': [0,
#   20,
#   40,
#   60,
#   80,
#   100,
#   120,
#   140,
#   160,
#   180,
#   200,
#   220,
#   240,
#   260,
#   280],
#  'validation_faces/4006': [0,
#   20,
#   40,
# ...
