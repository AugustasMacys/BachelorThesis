# %%
from google.cloud import storage
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= r"C:\Users\Augustas\Documents\Google Cloud\Final Year Project-89016ba0b812.json"
client = storage.Client()

# %%
bucket_fake = client.get_bucket("training_fake_faces")

# %%
fake_image_name = r"training_fake_faces/aabmgfhcgg/aabmgfhcgg_100.png"

# %%
blob = bucket_fake.get_blob(fake_image_name).download_as_string()

# %%
blob
# Out:
# <Blob: training_fake_faces, training_fake_faces/aabmgfhcgg/aabmgfhcgg_100.png, 1609707078964070>

# %%
import io
from PIL import Image

blob_in_bytes = io.BytesIO(blob)
img_fake = Image.open(blob_in_bytes).convert("RGB")

# %%
img_fake
# Out:
# <PIL.Image.Image image mode=RGB size=198x268 at 0x2C5D7853C88>
